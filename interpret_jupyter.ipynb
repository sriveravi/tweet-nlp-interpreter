# %%
# from https://shap.readthedocs.io/en/latest/example_notebooks/text_examples/sentiment_analysis/Using%20custom%20functions%20and%20tokenizers.html

import matplotlib
from numpy import vstack
import shap
from classify import get_features
from classify import reg as classifier
import numpy as np
from classify import class_names
# this defines an explicit python function that takes a list of strings and outputs scores for each class
def f(x):
    features = []
    for line in x:
        features.append(get_features(line))
    features = np.vstack(features)
    #     return classifier.predict(features)  # straight up decision
    return classifier.predict_proba(features)  # probability over each decision

# build an explainer by explicitly creating a masker
method = "default masker"
if method == "default masker":
    masker = shap.maskers.Text(r"\W") # this will create a basic whitespace tokenizer
    explainer = shap.Explainer(f, masker, output_names=class_names)
else:
    raise NotImplementedError("TODO: Implement more masker methods")

x = [
    'RT @dog_rates: This is Charlie. He has literal heart-eyes. 14/10 would be an honor to pet ', 
    'today we took a new route. during our walk. this is very exciting. i did not realize i had unlocked. this part of the map', 
    'i know. you have. some problems. right now. but. my problem. is that. you. are. not. petting me. and isn’t that. so… ',
    ]

# %%
f(x)
# Out:
# array([[0.00525601, 0.99474399],
#        [0.00245036, 0.99754964],
#        [0.99850448, 0.00149552]])

# %%
shap_values = explainer(x)
# Out:
# Partition explainer:  33%|████████████████▎                                | 1/3 [00:00<?, ?it/s]
#   0%|                                                                    | 0/248 [00:00<?, ?it/s]
#  59%|█████████████████████████████████▌                       | 146/248 [00:00<00:00, 611.55it/s]
#  85%|█████████████████████████████████████████████████▌        | 212/248 [00:02<00:00, 58.97it/s]
#  98%|████████████████████████████████████████████████████████▌ | 242/248 [00:04<00:00, 46.06it/s]
# Partition explainer: 100%|█████████████████████████████████████████| 3/3 [00:20<00:00,  4.90s/it]
#   0%|                                                                    | 0/248 [00:00<?, ?it/s]
#  59%|█████████████████████████████████▌                       | 146/248 [00:00<00:00, 570.85it/s]
#  83%|████████████████████████████████████████████████▏         | 206/248 [00:02<00:00, 65.55it/s]
#  95%|███████████████████████████████████████████████████████▏  | 236/248 [00:03<00:00, 48.67it/s]
# 254it [00:04, 42.16it/s]
# Partition explainer: 4it [00:29,  9.94s/it]

# %%
shap.plots.text(shap_values)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_rjbcxdeekiftojgfcfls = '_tp_rjbcxdeekiftojgfcfls_output_0';
#     document._zoom_rjbcxdeekiftojgfcfls = undefined;
#     function _output_onclick_rjbcxdeekiftojgfcfls(i) {
#         var next_id = undefined;
#
#         if (document._zoom_rjbcxdeekiftojgfcfls !== undefined) {
#             document.getElementById(document._zoom_rjbcxdeekiftojgfcfls+ '_zoom').style.display = 'none';
#
#             if (document._zoom_rjbcxdeekiftojgfcfls === '_tp_rjbcxdeekiftojgfcfls_output_' + i) {
#                 document.getElementById(document._zoom_rjbcxdeekiftojgfcfls).style.display = 'block';
#                 document.getElementById(document._zoom_rjbcxdeekiftojgfcfls+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_rjbcxdeekiftojgfcfls).style.display = 'none';
#                 document.getElementById(document._zoom_rjbcxdeekiftojgfcfls+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_rjbcxdeekiftojgfcfls !== '_tp_rjbcxdeekiftojgfcfls_output_' + i) {
#             next_id = '_tp_rjbcxdeekiftojgfcfls_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_rjbcxdeekiftojgfcfls = next_id;
#     }
#     function _output_onmouseover_rjbcxdeekiftojgfcfls(i, el) {
#         if (document._zoom_rjbcxdeekiftojgfcfls !== undefined) { return; }
#         if (document._hover_rjbcxdeekiftojgfcfls !== undefined) {
#             document.getElementById(document._hover_rjbcxdeekiftojgfcfls + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_rjbcxdeekiftojgfcfls).style.display = 'none';
#         }
#         document.getElementById('_tp_rjbcxdeekiftojgfcfls_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_rjbcxdeekiftojgfcfls = '_tp_rjbcxdeekiftojgfcfls_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_rjbcxdeekiftojgfcfls_output_0_name"
#     onclick="_output_onclick_rjbcxdeekiftojgfcfls(0)"
#     onmouseover="_output_onmouseover_rjbcxdeekiftojgfcfls(0, this);">cat</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_rjbcxdeekiftojgfcfls_output_1_name"
#     onclick="_output_onclick_rjbcxdeekiftojgfcfls(1)"
#     onmouseover="_output_onmouseover_rjbcxdeekiftojgfcfls(1, this);">dog</div><br><br><div id='_tp_rjbcxdeekiftojgfcfls_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.999999706731074%" y1="33" x2="49.999999706731074%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.999999706731074%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="38.26924286670912%" y1="33" x2="38.26924286670912%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="38.26924286670912%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="26.538486026687178%" y1="33" x2="26.538486026687178%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.538486026687178%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="14.807729186665227%" y1="33" x2="14.807729186665227%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="14.807729186665227%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="61.73075654675303%" y1="33" x2="61.73075654675303%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="61.73075654675303%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="73.46151338677497%" y1="33" x2="73.46151338677497%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="73.46151338677497%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="85.19227022679691%" y1="33" x2="85.19227022679691%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="85.19227022679691%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="21.22327119513009%" y1="33" x2="21.22327119513009%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="21.22327119513009%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.00937985</text><text x="21.22327119513009%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.00937985</text><text x="21.22327119513009%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="21.10947226221679%" y1="33" x2="21.10947226221679%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="21.10947226221679%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.00743967</text><text x="21.10947226221679%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.00743967</text><text x="21.10947226221679%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">cat</tspan>(inputs)</text><rect x="11.489116125248099%" width="9.62035613696869%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="16.69944029869288%" x2="21.10947226221679%" y1="60" y2="60" id="_fb_ifwceajqijfmrnxjmczf_ind_12" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="18.904456280454838%" y="71" font-size="12px" id="_fs_ifwceajqijfmrnxjmczf_ind_12" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.075</text><svg x="16.69944029869288%" y="40" height="20" width="4.41003196352391%">  <svg x="0" y="0" width="100%" height="100%">     ...
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[1]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_ycqmiwsznxnkfrdwptau = '_tp_ycqmiwsznxnkfrdwptau_output_0';
#     document._zoom_ycqmiwsznxnkfrdwptau = undefined;
#     function _output_onclick_ycqmiwsznxnkfrdwptau(i) {
#         var next_id = undefined;
#
#         if (document._zoom_ycqmiwsznxnkfrdwptau !== undefined) {
#             document.getElementById(document._zoom_ycqmiwsznxnkfrdwptau+ '_zoom').style.display = 'none';
#
#             if (document._zoom_ycqmiwsznxnkfrdwptau === '_tp_ycqmiwsznxnkfrdwptau_output_' + i) {
#                 document.getElementById(document._zoom_ycqmiwsznxnkfrdwptau).style.display = 'block';
#                 document.getElementById(document._zoom_ycqmiwsznxnkfrdwptau+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_ycqmiwsznxnkfrdwptau).style.display = 'none';
#                 document.getElementById(document._zoom_ycqmiwsznxnkfrdwptau+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_ycqmiwsznxnkfrdwptau !== '_tp_ycqmiwsznxnkfrdwptau_output_' + i) {
#             next_id = '_tp_ycqmiwsznxnkfrdwptau_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_ycqmiwsznxnkfrdwptau = next_id;
#     }
#     function _output_onmouseover_ycqmiwsznxnkfrdwptau(i, el) {
#         if (document._zoom_ycqmiwsznxnkfrdwptau !== undefined) { return; }
#         if (document._hover_ycqmiwsznxnkfrdwptau !== undefined) {
#             document.getElementById(document._hover_ycqmiwsznxnkfrdwptau + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_ycqmiwsznxnkfrdwptau).style.display = 'none';
#         }
#         document.getElementById('_tp_ycqmiwsznxnkfrdwptau_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_ycqmiwsznxnkfrdwptau = '_tp_ycqmiwsznxnkfrdwptau_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_ycqmiwsznxnkfrdwptau_output_0_name"
#     onclick="_output_onclick_ycqmiwsznxnkfrdwptau(0)"
#     onmouseover="_output_onmouseover_ycqmiwsznxnkfrdwptau(0, this);">cat</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_ycqmiwsznxnkfrdwptau_output_1_name"
#     onclick="_output_onclick_ycqmiwsznxnkfrdwptau(1)"
#     onmouseover="_output_onmouseover_ycqmiwsznxnkfrdwptau(1, this);">dog</div><br><br><div id='_tp_ycqmiwsznxnkfrdwptau_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.999999706731074%" y1="33" x2="49.999999706731074%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.999999706731074%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="38.26924286670912%" y1="33" x2="38.26924286670912%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="38.26924286670912%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="26.538486026687178%" y1="33" x2="26.538486026687178%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.538486026687178%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="14.807729186665227%" y1="33" x2="14.807729186665227%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="14.807729186665227%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="61.73075654675303%" y1="33" x2="61.73075654675303%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="61.73075654675303%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="73.46151338677497%" y1="33" x2="73.46151338677497%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="73.46151338677497%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="85.19227022679691%" y1="33" x2="85.19227022679691%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="85.19227022679691%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="21.22327119513009%" y1="33" x2="21.22327119513009%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="21.22327119513009%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.00937985</text><text x="21.22327119513009%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.00937985</text><text x="21.22327119513009%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="20.816830422466516%" y1="33" x2="20.816830422466516%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="20.816830422466516%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.00245036</text><text x="20.816830422466516%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.00245036</text><text x="20.816830422466516%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">cat</tspan>(inputs)</text><rect x="3.503341801466385%" width="17.31348862100013%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="15.799907473059905%" x2="20.816830422466516%" y1="60" y2="60" id="_fb_mqckpodktxcaeoghmhxc_ind_9" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="18.30836894776321%" y="71" font-size="12px" id="_fs_mqckpodktxcaeoghmhxc_ind_9" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.086</text><svg x="15.799907473059905%" y="40" height="20" width="5.016922949406611%">  <svg x="0" y="0" width="100%" height="100% ...
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[2]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_uhdpnzlpgjdikqnjqkun = '_tp_uhdpnzlpgjdikqnjqkun_output_0';
#     document._zoom_uhdpnzlpgjdikqnjqkun = undefined;
#     function _output_onclick_uhdpnzlpgjdikqnjqkun(i) {
#         var next_id = undefined;
#
#         if (document._zoom_uhdpnzlpgjdikqnjqkun !== undefined) {
#             document.getElementById(document._zoom_uhdpnzlpgjdikqnjqkun+ '_zoom').style.display = 'none';
#
#             if (document._zoom_uhdpnzlpgjdikqnjqkun === '_tp_uhdpnzlpgjdikqnjqkun_output_' + i) {
#                 document.getElementById(document._zoom_uhdpnzlpgjdikqnjqkun).style.display = 'block';
#                 document.getElementById(document._zoom_uhdpnzlpgjdikqnjqkun+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_uhdpnzlpgjdikqnjqkun).style.display = 'none';
#                 document.getElementById(document._zoom_uhdpnzlpgjdikqnjqkun+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_uhdpnzlpgjdikqnjqkun !== '_tp_uhdpnzlpgjdikqnjqkun_output_' + i) {
#             next_id = '_tp_uhdpnzlpgjdikqnjqkun_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_uhdpnzlpgjdikqnjqkun = next_id;
#     }
#     function _output_onmouseover_uhdpnzlpgjdikqnjqkun(i, el) {
#         if (document._zoom_uhdpnzlpgjdikqnjqkun !== undefined) { return; }
#         if (document._hover_uhdpnzlpgjdikqnjqkun !== undefined) {
#             document.getElementById(document._hover_uhdpnzlpgjdikqnjqkun + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_uhdpnzlpgjdikqnjqkun).style.display = 'none';
#         }
#         document.getElementById('_tp_uhdpnzlpgjdikqnjqkun_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_uhdpnzlpgjdikqnjqkun = '_tp_uhdpnzlpgjdikqnjqkun_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_uhdpnzlpgjdikqnjqkun_output_0_name"
#     onclick="_output_onclick_uhdpnzlpgjdikqnjqkun(0)"
#     onmouseover="_output_onmouseover_uhdpnzlpgjdikqnjqkun(0, this);">cat</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_uhdpnzlpgjdikqnjqkun_output_1_name"
#     onclick="_output_onclick_uhdpnzlpgjdikqnjqkun(1)"
#     onmouseover="_output_onmouseover_uhdpnzlpgjdikqnjqkun(1, this);">dog</div><br><br><div id='_tp_uhdpnzlpgjdikqnjqkun_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.999999706731074%" y1="33" x2="49.999999706731074%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.999999706731074%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="38.26924286670912%" y1="33" x2="38.26924286670912%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="38.26924286670912%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="26.538486026687178%" y1="33" x2="26.538486026687178%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.538486026687178%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="14.807729186665227%" y1="33" x2="14.807729186665227%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="14.807729186665227%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="61.73075654675303%" y1="33" x2="61.73075654675303%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="61.73075654675303%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="73.46151338677497%" y1="33" x2="73.46151338677497%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="73.46151338677497%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="85.19227022679691%" y1="33" x2="85.19227022679691%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="85.19227022679691%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="21.22327119513009%" y1="33" x2="21.22327119513009%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="21.22327119513009%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.00937985</text><text x="21.22327119513009%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.00937985</text><text x="21.22327119513009%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="79.2582217732163%" y1="33" x2="79.2582217732163%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.2582217732163%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.998829</text><text x="79.2582217732163%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.998829</text><text x="79.2582217732163%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">cat</tspan>(inputs)</text><rect x="10.996783249930171%" width="68.26143852328612%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="71.02466386050409%" x2="79.2582217732163%" y1="60" y2="60" id="_fb_qptqajudvkuzckiwxlyd_ind_4" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="75.1414428168602%" y="71" font-size="12px" id="_fs_qptqajudvkuzckiwxlyd_ind_4" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.14</text><svg x="71.02466386050409%" y="40" height="20" width="8.233557912712214%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" ...
